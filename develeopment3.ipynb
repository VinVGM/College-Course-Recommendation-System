# %%
import pandas
#from keyword_gen_and_fixer import keyword_gen, keyword_fixer

# %%
csv = "dataset/ecm_curriculum.csv"
courses_df = pandas.read_csv(csv)
courses_df
# Out:
#     Unnamed: 0 Course Code                         course_title_l  \
# 0            0    BCHY101L                  Engineering Chemistry
# 1            1    BCHY101P              Engineering Chemistry Lab
# 2            2    BMAT101L                               Calculus
# 3            3    BMAT101P                           Calculus Lab
# 4            4    BMAT102L  Differential Equations and Transforms
# ..         ...         ...                                    ...
# 94          94    BECM101N            Introduction to Engineering
# 95          95    BEXC100N            Extra curricular activities
# 96          96    BHUM101N                      Ethics and Values
# 97          97    BSSC101N       Essence of Traditional Knowledge
# 98          98    BSSC102N                    Indian Constitution
#
#                                              keywords
# 0   ['engineering chemistry', 'chemistry', 'engine...
# 1   ['engineering chemistry lab', 'chemistry lab',...
# 2                                        ['calculus']
# 3                 ['calculus lab', 'calculus', 'lab']
# 4   ['differential equations transforms', 'equatio...
# ..                                                ...
# 94  ['introduction engineering', 'engineering', 'i...
# 95  ['extra curricular activities', 'extra curricu...
# 96              ['ethics values', 'ethics', 'values']
# 97  ['traditional knowledge', 'essence traditional...
# 98  ['indian constitution', 'constitution', 'indian']
#
# [99 rows x 4 columns]

# %%
courses_df
